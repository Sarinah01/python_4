# %%
import requests, json

# %%
api_key = "d86e01819688f523bad31eab1e9aa2bb"
city="Surat"
url = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}"
res = requests.get(url)
res.status_code
result = res.json()

# %%
lat =result[0]["lat"]

# %%
lon =result[0]["lon"]

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
res= requests.get(url)
res.status_code
# Out:
# 200

# %%
result2 = res.json()

result2
# Out:
# {'coord': {'lon': 3.2553, 'lat': 45.9383},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 290.23,
#   'feels_like': 290,
#   'temp_min': 290.23,
#   'temp_max': 290.23,
#   'pressure': 1012,
#   'humidity': 77,
#   'sea_level': 1012,
#   'grnd_level': 970},
#  'visibility': 10000,
#  'wind': {'speed': 1.03, 'deg': 0},
#  'clouds': {'all': 75},
#  'dt': 1780375953,
#  'sys': {'type': 1,
#   'id': 6496,
#   'country': 'FR',
#   'sunrise': 1780372785,
#   'sunset': 1780428628},
#  'timezone': 7200,
#  'id': 2979447,
#  'name': 'Saint-Ignat',
#  'cod': 200}

# %%
temp = result2["main"]["temp"]
temp
# Out:
# 290.23

# %%
temp_min = result2["main"]["temp_min"]
temp_min
# Out:
# 290.23

# %%
temp_max = result2["main"]["temp_max"]
temp_max
# Out:
# 290.23

# %%
humidity = result2["main"]["humidity"]
humidity
# Out:
# 77

# %%
pressure = result2["main"]["pressure"]
pressure
# Out:
# 1012

# %%
clouds = result2["clouds"]["all"]
clouds
# Out:
# 75

# %%
print(json.dumps(result2,indent=5))
# Out:
# {
#      "coord": {
#           "lon": 3.2553,
#           "lat": 45.9383
#      },
#      "weather": [
#           {
#                "id": 803,
#                "main": "Clouds",
#                "description": "broken clouds",
#                "icon": "04d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 290.23,
#           "feels_like": 290,
#           "temp_min": 290.23,
#           "temp_max": 290.23,
#           "pressure": 1012,
#           "humidity": 77,
#           "sea_level": 1012,
#           "grnd_level": 970
#      },
#      "visibility": 10000,
#      "wind": {
#           "speed": 1.03,
#           "deg": 0
#      },
#      "clouds": {
#           "all": 75
#      },
#      "dt": 1780375953,
#      "sys": {
#           "type": 1,
#           "id": 6496,
#           "country": "FR",
#           "sunrise": 1780372785,
#           "sunset": 1780428628
#      },
#      "timezone": 7200,
#      "id": 2979447,
# ...

# %%
url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
result3 = res.json()

# %%
result3
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1780380000,
#    'main': {'temp': 290.23,
#     'feels_like': 290,
#     'temp_min': 289.59,
#     'temp_max': 290.23,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 970,
#     'humidity': 77,
#     'temp_kf': 0.64},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 1.98, 'deg': 177, 'gust': 3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-06-02 06:00:00'},
#   {'dt': 1780390800,
#    'main': {'temp': 290.49,
#     'feels_like': 290.37,
#     'temp_min': 290.49,
#     'temp_max': 291,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 969,
#     'humidity': 80,
#     'temp_kf': -0.51},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
# ...

# %%
print(f"temp_min --" , result3['list'][0]['main']['temp_min'])
print(f"temp_max --" , result3['list'][0]['main']['temp_max'])
print(f"temp --" , result3['list'][0]['main']['temp'])
print(f"pressure --" , result3['list'][0]['main']['pressure'])
print(f"clouds --" , result3['list'][0]['clouds']['all'])
# Out:
# temp_min -- 289.59
# temp_max -- 290.23
# temp -- 290.23
# pressure -- 1012
# clouds -- 75
