# %%
import pandas as pd
df = pd.read_csv('train.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.set_index('Name', drop = True)
print(df)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                   22
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.loc['Braund, Mr. Owen Harris':'Dooley, Mr. Patrick',:'Ticket']
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df['child']=df['Parch']+df['SibSp']

# %%
df.loc['Braund, Mr. Owen Harris':'Dooley, Mr. Patrick',:]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
import numpy as np
n = np.random.randint(1,100,(8,5))
print(n)
print(n.shape)
print(n.size)
print(n.ndim)

# x= np.concatenate(n, axis=0)
# x = np.sum(n, axis=0)
# print(x)

df = pd.DataFrame(n,columns=['a','b','c','d','e'])
df['sum'] = df['a']+df['b']+df['c']+df['d']+df['e']
df.loc[6,2]=7
df.loc[5:7,'b':'d']
df.loc[9]=[50,60,70,80,90,100,110]
print(df)
# Out:
# [[ 4 14 13  7 19]
#  [45  5  2 76 40]
#  [14 79 93 69 26]
#  [ 1 46 62 68 99]
#  [85 48 75 76 26]
#  [33 96 33 89 61]
#  [59 55 65  7 97]
#  [39 85 34 23 56]]
# (8, 5)
# 40
# 2
#     a   b   c   d   e  sum      2
# 0   4  14  13   7  19   57    NaN
# 1  45   5   2  76  40  168    NaN
# 2  14  79  93  69  26  281    NaN
# 3   1  46  62  68  99  276    NaN
# 4  85  48  75  76  26  310    NaN
# 5  33  96  33  89  61  312    NaN
# 6  59  55  65   7  97  283    7.0
# 7  39  85  34  23  56  237    NaN
# 9  50  60  70  80  90  100  110.0

# %%
df = pd.DataFrame(np.random.randint(1,100,(5,4)), columns = ['courseid','courseName','credits','faculty'])
print(df)
# Out:
#    courseid  courseName  credits  faculty
# 0        63          38       73       36
# 1        37          23       35       30
# 2        48          92       17       36
# 3        46          49       68        7
# 4        98          75       75       80

# %%
df.head()
# Out:
#    courseid  courseName  credits  faculty
# 0        63          38       73       36

# %%
df.tail()
# Out:
#    courseid  courseName  credits  faculty
# 0        63          38       73       36
# 1        37          23       35       30
# 2        48          92       17       36
# 3        46          49       68        7
# 4        98          75       75       80

# %%
df.tail(4)
# Out:
#    courseid  courseName  credits  faculty
# 1        37          23       35       30
# 2        48          92       17       36
# 3        46          49       68        7
# 4        98          75       75       80

# %%
df.sample()
# Out:
#    courseid  courseName  credits  faculty
# 0        63          38       73       36

# %%
df.sample(5)
# random data
# Out:
#    courseid  courseName  credits  faculty
# 2        48          92       17       36
# 1        37          23       35       30
# 0        63          38       73       36
# 4        98          75       75       80
# 3        46          49       68        7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   courseid    5 non-null      int32
#  1   courseName  5 non-null      int32
#  2   credits     5 non-null      int32
#  3   faculty     5 non-null      int32
# dtypes: int32(4)
# memory usage: 208.0 bytes

# %%
df.describe()
# Out:
#         courseid  courseName  credits   faculty
# count   5.000000    5.000000   5.0000   5.00000
# mean   58.400000   55.400000  53.6000  37.80000
# std    24.027068   27.915945  26.1113  26.44239
# min    37.000000   23.000000  17.0000   7.00000
# 25%    46.000000   38.000000  35.0000  30.00000
# 50%    48.000000   49.000000  68.0000  36.00000
# 75%    63.000000   75.000000  73.0000  36.00000
# max    98.000000   92.000000  75.0000  80.00000

# %%
df.describe(include='all')
# Out:
#         courseid  courseName  credits   faculty
# count   5.000000    5.000000   5.0000   5.00000
# mean   58.400000   55.400000  53.6000  37.80000
# std    24.027068   27.915945  26.1113  26.44239
# min    37.000000   23.000000  17.0000   7.00000
# 25%    46.000000   38.000000  35.0000  30.00000
# 50%    48.000000   49.000000  68.0000  36.00000
# 75%    63.000000   75.000000  73.0000  36.00000
# max    98.000000   92.000000  75.0000  80.00000
